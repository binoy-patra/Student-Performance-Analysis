# %% [markdown]
# # Student Performance Analysis
#
#
# ### Work Flow :
# 1. Importing required modules
# 2. Loading the data
# 3. Viweing the data
# 4. Extracting Basic Information about the Dataset:
#     a. How big is the data?
#     b. How does the data look like?
#     c. What is datatypes of the collumn?
#     d. How does the data looks mathematically?
#     e. Are there any missing values?
#     f. Are there any duplicates values?
#     g. How is the correlation of the data?
# 5. Nulls and Duplicates Checking and Imputation(If any)
# 6. EDA (Univariate Analysis AND Multivariate Analysis)
# 7. Basic Questions

# %% [markdown]
# ## Importing required modules

# %%
# To Load, Transform and Anlyze data
import numpy as np 
import pandas as pd

# To Visualize data
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns
plt.rcParams['figure.figsize']=[10,5]

# To aavoid any Warnings 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading and Viewing the data

# %%
# Loading the dataset
df= pd.read_csv("Expanded_data_with_more_features.csv")

# %%
# First 5 Records 
df.head(5)
# Out:
#    Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType TestPrep  \
# 0           0  female         NaN   bachelor's degree      standard     none
# 1           1  female     group C        some college      standard      NaN
# 2           2  female     group B     master's degree      standard     none
# 3           3    male     group A  associate's degree  free/reduced     none
# 4           4    male     group C        some college      standard     none
#
#   ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0             married     regularly          yes         3.0     school_bus
# 1             married     sometimes          yes         0.0            NaN
# 2              single     sometimes          yes         4.0     school_bus
# 3             married         never           no         1.0            NaN
# 4             married     sometimes          yes         0.0     school_bus
#
# ...

# %%
# Last 5 Records
df.tail(5)
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female         NaN         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 30636       none              single     sometimes           no         2.0
# 30637       none              single     regularly           no         1.0
# 30638  completed             married     sometimes           no         1.0
# 30639  completed             married     regularly           no         3.0
# 30640       none             married         never           no         1.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# ...

# %%
# Random 5 records 
df.sample(5)
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc LunchType  \
# 4969          233  female         NaN        some college  standard
# 23894         462    male     group E        some college  standard
# 28407         307  female     group C    some high school  standard
# 30410         379  female         NaN  associate's degree  standard
# 14593         481    male     group D   bachelor's degree  standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 4969         NaN             married     regularly          yes         3.0
# 23894       none             married     sometimes           no         1.0
# 28407  completed             married     regularly           no         1.0
# 30410  completed             married     sometimes           no         2.0
# 14593       none             married     regularly          yes         3.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# ...

# %% [markdown]
# ## Extracting Basic Information about the Dataset

# %%
# Shape
df.shape
# Out:
# (30641, 15)

# %%
# Index
df.index
# Out:
# RangeIndex(start=0, stop=30641, step=1)

# %%
# Column names 
df.columns
# Out:
# Index(['Unnamed: 0', 'Gender', 'EthnicGroup', 'ParentEduc', 'LunchType',
#        'TestPrep', 'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild',
#        'NrSiblings', 'TransportMeans', 'WklyStudyHours', 'MathScore',
#        'ReadingScore', 'WritingScore'],
#       dtype='object')

# %%
# Data Types 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30641 entries, 0 to 30640
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           30641 non-null  int64
#  1   Gender               30641 non-null  object
#  2   EthnicGroup          28801 non-null  object
#  3   ParentEduc           28796 non-null  object
#  4   LunchType            30641 non-null  object
#  5   TestPrep             28811 non-null  object
#  6   ParentMaritalStatus  29451 non-null  object
#  7   PracticeSport        30010 non-null  object
#  8   IsFirstChild         29737 non-null  object
#  9   NrSiblings           29069 non-null  float64
#  10  TransportMeans       27507 non-null  object
#  11  WklyStudyHours       29686 non-null  object
#  12  MathScore            30641 non-null  int64
#  13  ReadingScore         30641 non-null  int64
#  14  WritingScore         30641 non-null  int64
# ...

# %%
# Unique value accross columns
df.nunique()
# Out:
# Unnamed: 0             1000
# Gender                    2
# EthnicGroup               5
# ParentEduc                6
# LunchType                 2
# TestPrep                  2
# ParentMaritalStatus       4
# PracticeSport             3
# IsFirstChild              2
# NrSiblings                8
# TransportMeans            2
# WklyStudyHours            3
# MathScore                95
# ReadingScore             90
# WritingScore             93
# dtype: int64

# %%
# Statistical Overview
df.describe()
# Out:
#          Unnamed: 0    NrSiblings     MathScore  ReadingScore  WritingScore
# count  30641.000000  29069.000000  30641.000000  30641.000000  30641.000000
# mean     499.556607      2.145894     66.558402     69.377533     68.418622
# std      288.747894      1.458242     15.361616     14.758952     15.443525
# min        0.000000      0.000000      0.000000     10.000000      4.000000
# 25%      249.000000      1.000000     56.000000     59.000000     58.000000
# 50%      500.000000      2.000000     67.000000     70.000000     69.000000
# 75%      750.000000      3.000000     78.000000     80.000000     79.000000
# max      999.000000      7.000000    100.000000    100.000000    100.000000

# %% [markdown]
# ### Conclussion:
#
# 1. This dataset includes scores from three test scores of students at a (fictional) public school and a variety of personal and socio-economic factors that may have interaction effects upon them.
# 2. This dataset has more data >30k records and 15 Columns.
# 3. Data Dictionary (column description):
#
#
#     0. unnamed: 0 :maybe index
#     1. Gender: Gender of the student (male/female)
#     2. EthnicGroup: Ethnic group of the student (group A to E)
#     3. ParentEduc: Parent(s) education background (from some_highschool to master's degree)
#     4. LunchType: School lunch type (standard or free/reduced)
#     5. TestPrep: Test preparation course followed (completed or none)
#     6. ParentMaritalStatus: Parent(s) marital status (married/single/widowed/divorced)
#     7. PracticeSport: How often the student parctice sport (never/sometimes/regularly))
#     8. IsFirstChild: If the child is first child in the family or not (yes/no)
#     9. NrSiblings: Number of siblings the student has (0 to 7)
#     10. TransportMeans: Means of transport to school (schoolbus/private)
#     11. WklyStudyHours: Weekly self-study hours(less that 5hrs; between 5 and 10hrs; more than 10hrs)
#     12. MathScore: math test score(0-100)
#     13. ReadingScore: reading test score(0-100)
#     14. WritingScore: writing test score(0-100)

# %% [markdown]
# ## Nulls and Duplicates Checking

# %%
df.isna().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup            1840
# ParentEduc             1845
# LunchType                 0
# TestPrep               1830
# ParentMaritalStatus    1190
# PracticeSport           631
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Conclussion:
# 1. Column 'Unmaned 0' has no contribution or meaning. We can drop it.
# 2. 'EthnicGroup', 'ParentEduc','TestPrep', 'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild', 'NrSiblings', 'TransportMeans', 'WklyStudyHours'
# column has null values.

# %% [markdown]
# ## Data Cleaning & Pre-processing

# %%
# Dropping unnecessary columns
df.drop('Unnamed: 0',axis=1,inplace=True)

# Null value imputation 
df['EthnicGroup'].fillna('unknown',inplace=True)
df['ParentEduc'].fillna('unknown',inplace=True)
df['TestPrep'].fillna('none',inplace=True)
df['ParentMaritalStatus'].fillna('unknown',inplace=True)
df['PracticeSport'].fillna('never',inplace=True)
df['IsFirstChild'].fillna('no',inplace=True)
df['NrSiblings'].fillna(0.0,inplace=True)
df['TransportMeans'].fillna('unknown',inplace=True)
df['WklyStudyHours'].fillna('<5',inplace=True)

# Column Transformation
df['WklyStudyHours']=df['WklyStudyHours'].str.replace('05-Oct','5-10')

# %%
df.isna().sum()
# Out:
# Gender                 0
# EthnicGroup            0
# ParentEduc             0
# LunchType              0
# TestPrep               0
# ParentMaritalStatus    0
# PracticeSport          0
# IsFirstChild           0
# NrSiblings             0
# TransportMeans         0
# WklyStudyHours         0
# MathScore              0
# ReadingScore           0
# WritingScore           0
# dtype: int64

# %% [markdown]
# ## EDA & Data Visualization

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Gender Distribution

# %%
df['Gender'].value_counts()
# Out:
# female    15424
# male      15217
# Name: Gender, dtype: int64

# %%
# Gender Distribution
ax= sns.countplot(df['Gender'])
ax.set(xlabel='Gender',ylabel='Count',title='Distribution of Gender')
plt.show()

# %% [markdown]
# ### Conclussion:
# It seems there are slightly more female students (15,424) than male students (15,217). This slight difference suggests a balanced gender distribution among the students under analysis.

# %% [markdown]
# ### Ethnic Group Distribution

# %%
df['EthnicGroup'].value_counts()
# Out:
# group C    9212
# group D    7503
# group B    5826
# group E    4041
# group A    2219
# unknown    1840
# Name: EthnicGroup, dtype: int64

# %%
# Ethnic Group Distribution
plt.figure(figsize=(13,5))
ax= sns.countplot(df['EthnicGroup'])
ax.set(xlabel='Ethnic Group',ylabel='Count',title='Distribution of Ethnic Group')
plt.show()

# %% [markdown]
# ### Conclussion:
# - Group C has the highest representation among the identified groups, with 9,212 students.
# - Following Group C, Group D is the next most represented with 7,503 students.
# - Group B and Group E follow with 5,826 and 4,041 students respectively.
# - Group A is the smallest identified group with 2,219 students.
# - Additionally, there are 1,840 students whose ethnic group is unknown.
# This distribution provides a snapshot of the diversity within the student population across various ethnic groups. Understanding these demographics can be crucial for educational institutions to tailor support, resources, and programs to meet the diverse needs of their student body effectively.

# %% [markdown]
# ### Parents Education Distribution

# %%
df['ParentEduc'].value_counts()
# Out:
# some college          6633
# high school           5687
# associate's degree    5550
# some high school      5517
# bachelor's degree     3386
# master's degree       2023
# unknown               1845
# Name: ParentEduc, dtype: int64

# %%
# Parents Education Distribution
plt.figure(figsize=(13,5))
ax= sns.countplot(df['ParentEduc'])
ax.set(xlabel='Parents Education',ylabel='Count',title='Distribution of Parents Education')
plt.show()

# %% [markdown]
# ### Conclussion:
# - The most common education level among parents is "some college" with 6,633 individuals.
# - Following closely are those who completed high school (5,687) and those with an associate's degree (5,550).
# - A similar number of parents have completed "some high school" (5,517) and "associate's degree" (5,550).
# - Bachelor's degree holders are fewer in number compared to other categories, with 3,386 parents.
# - A smaller proportion have attained a master's degree (2,023), while 1,845 parents' education levels are unknown.
#
# Understanding the distribution of parents' education levels is vital for educational institutions and policymakers. It provides insights into the educational backgrounds of students' families, which can influence academic outcomes, aspirations, and the level of support needed for students to succeed. This information can guide efforts to enhance educational equity and support students from diverse family backgrounds effectively.

# %% [markdown]
# ### Lunch Type Distribution

# %%
df['LunchType'].value_counts()
# Out:
# standard        19905
# free/reduced    10736
# Name: LunchType, dtype: int64

# %%
# Lunch Type Distribution
ax= sns.countplot(df['LunchType'])
ax.set(xlabel='Types of Lunch',ylabel='Count',title='Distribution of Lunch Type')
plt.show()

# %% [markdown]
# ### Conclussion:
# - The majority of students, 19,905 in total, are on a standard lunch plan.
# - A significant number, 10,736 students, are on a free/reduced lunch plan.
#
# The distribution of lunch types can indicate socioeconomic factors that may impact students' academic performance and overall well-being. Students on free/reduced lunch plans may face additional challenges related to food security and economic stability, which can influence their educational outcomes. Understanding and addressing these disparities can be crucial for creating supportive environments that promote equitable educational opportunities for all students.

# %% [markdown]
# ### Test Preparation Distribution

# %%
df['TestPrep'].value_counts()
# Out:
# none         20686
# completed     9955
# Name: TestPrep, dtype: int64

# %%
# Test Preparation Distribution
ax= sns.countplot(df['TestPrep'])
ax.set(xlabel='Preperation',ylabel='Count',title='Distribution of Test Preperation')
plt.show()

# %% [markdown]
# ### Conclussion:
# - The majority of students, 20,686 in total, did not complete any test preparation.
# - A significant number, 9,955 students, completed test preparation.
#
# This distribution highlights the varying levels of preparedness among students for standardized tests. Students who completed test preparation may have better performance outcomes compared to those who did not prepare. Addressing disparities in access to and completion of test preparation can play a crucial role in ensuring that all students have equitable opportunities to succeed academically.

# %% [markdown]
# ### Distribution of Parent Marital Status

# %%
df['ParentMaritalStatus'].value_counts()
# Out:
# married     16844
# single       7097
# divorced     4919
# unknown      1190
# widowed       591
# Name: ParentMaritalStatus, dtype: int64

# %%
# Distribution of Parent Marital Status
ax= sns.countplot(df['ParentMaritalStatus'])
ax.set(xlabel='Marital Status of Patrent',ylabel='Count',title='Distribution of Parent Marital Status')
plt.show()

# %% [markdown]
# ### Conclussion:
# - The largest group consists of married parents, totaling 16,844.
# - Following married parents, there are 7,097 single parents.
# - Additionally, 4,919 parents are divorced, 591 are widowed, and 1,190 have an unknown marital status.
#
# This distribution provides insights into the diverse family structures and marital statuses among the parents of students. Understanding these demographics can help educators and policymakers tailor support and resources to meet the varied needs of students from different family backgrounds.

# %% [markdown]
# ### Distribution of Sports Involvement

# %%
df['PracticeSport'].value_counts()
# Out:
# sometimes    15213
# regularly    10793
# never         4635
# Name: PracticeSport, dtype: int64

# %%
# Distribution of Sports Involvement
ax= sns.countplot(df['PracticeSport'])
ax.set(xlabel='Sports Involvement',ylabel='Count',title='Distribution of Sports Involvement')
plt.show()

# %% [markdown]
# ### Conclussion:
# - A majority of students, 15,213, participate in sports sometimes.
# - A significant number, 10,793 students, are involved in sports regularly.
# - A smaller group, 4,635 students, do not participate in sports at all (never).
#
# This distribution indicates varying levels of engagement in sports among students. Regular sports involvement can contribute positively to physical health, social skills, and overall academic performance. Understanding these patterns can help educators and schools promote active lifestyles and provide appropriate support for students' extracurricular activities.

# %% [markdown]
# ### Distribution of wheather student is the first child or not

# %%
df['IsFirstChild'].value_counts()
# Out:
# yes    19082
# no     11559
# Name: IsFirstChild, dtype: int64

# %%
# Distribution of wheather student is the first child or not
ax= sns.countplot(df['IsFirstChild'])
ax.set(ylabel='Count', title='Distribution of whether Student is the First Child or Not')
plt.show()

# %% [markdown]
# ### Conclussion:
# The analysis reveals that a majority of students (19,082) are reported as being the first child, while a significant portion (11,559) are not.
# This distribution provides insights into family dynamics among the student population, highlighting a predominant trend towards being the first child among the students in the dataset.

# %% [markdown]
# ### Number of Siblings

# %%
df['NrSiblings'].value_counts()
# Out:
# 1.0    8217
# 2.0    6790
# 3.0    6123
# 0.0    4657
# 4.0    2941
# 5.0    1320
# 6.0     302
# 7.0     291
# Name: NrSiblings, dtype: int64

# %%
# Distribution of Siblings
ax= sns.countplot(df['NrSiblings'])
ax.set(xlabel='Number of Siblings',ylabel='Count',title='Number of Siblings')
plt.show()

# %% [markdown]
# ### Conclussion:
# The distribution indicates that the majority of students have either 1 or 2 siblings, with 8,217 students having 1 sibling and 6,790 students having 2 siblings.
# This suggests that a significant number of students come from families with relatively fewer siblings.
# The presence of students with 0 siblings (4,657) and higher numbers of siblings (3, 4, 5, 6, and 7) further reflects the diversity in family sizes within the dataset.

# %% [markdown]
# ### Distribution of Transport Medium

# %%
df['TransportMeans'].value_counts()
# Out:
# school_bus    16145
# private       11362
# unknown        3134
# Name: TransportMeans, dtype: int64

# %%
# Distribution of Transport Medium
ax= sns.countplot(df['TransportMeans'])
ax.set(xlabel='Transport Medium',ylabel='Count',title='Distribution of Transport Medium')
plt.show()

# %% [markdown]
# ### Conclussion:
# The dataset reveals that a majority of students (16,145) use the school bus as their primary mode of transportation.
# A substantial number of students (11,362) use private transport, while a smaller group (3,134) have their transport medium categorized as unknown.
#
# Understanding the distribution of transport modes can provide insights into commuting patterns and possibly socioeconomic factors influencing transportation choices among students.

# %% [markdown]
# ### Distribution of Weekly Study Hours

# %%
df['WklyStudyHours'].value_counts()
# Out:
# 5 - 10    16246
# < 5        8238
# > 10       5202
# <5          955
# Name: WklyStudyHours, dtype: int64

# %%
# Distribution of Weekly Study Hours
ax= sns.countplot(df['WklyStudyHours'])
ax.set(xlabel='Weekly Study Hours',ylabel='Count',title='Distribution of Weekly Study Hours')
plt.show()

# %% [markdown]
# ### Conclussion:
# The data shows that the majority of students (16,246) study between 5 to 10 hours per week.
# A significant portion (8,238) studies less than 5 hours weekly, while 5,202 students dedicate more than 10 hours to their studies.
#
# Understanding these study hour distributions can provide insights into student academic habits and potential correlations with academic performance or other factors like extracurricular activities and personal commitments.

# %% [markdown]
# ### Statistical Analysis of MathScore,ReadingScore, WritingScore

# %%
sns.distplot(df['MathScore'],bins=4)
# Out:
# <AxesSubplot:xlabel='MathScore', ylabel='Density'>

# %%
sns.distplot(df['ReadingScore'],bins=4)
# Out:
# <AxesSubplot:xlabel='ReadingScore', ylabel='Density'>

# %%
sns.distplot(df['WritingScore'],bins=4)
# Out:
# <AxesSubplot:xlabel='WritingScore', ylabel='Density'>

# %%
df[['MathScore','ReadingScore', 'WritingScore']].describe()
# Out:
#           MathScore  ReadingScore  WritingScore
# count  30641.000000  30641.000000  30641.000000
# mean      66.558402     69.377533     68.418622
# std       15.361616     14.758952     15.443525
# min        0.000000     10.000000      4.000000
# 25%       56.000000     59.000000     58.000000
# 50%       67.000000     70.000000     69.000000
# 75%       78.000000     80.000000     79.000000
# max      100.000000    100.000000    100.000000

# %% [markdown]
# ### Conclussion
#
# - MathScore: The average math score is 66.56, with a standard deviation of 15.36. Scores range from 0 to 100, with the majority falling between 56 and 78.
#
# - ReadingScore: The average reading score is 69.38, with a standard deviation of 14.76. Scores range from 10 to 100, with the majority falling between 59 and 80.
#
# - WritingScore: The average writing score is 68.42, with a standard deviation of 15.44. Scores range from 4 to 100, with the majority falling between 58 and 79.
#
# These statistics indicate that while the average scores are relatively close across Math, Reading, and Writing, there is variability in individual performance. The scores follow a somewhat normal distribution with varying ranges, suggesting diverse levels of proficiency among students in these academic subjects.

# %%
df[['MathScore','ReadingScore', 'WritingScore']].corr()
# Out:
#               MathScore  ReadingScore  WritingScore
# MathScore      1.000000      0.817825      0.807118
# ReadingScore   0.817825      1.000000      0.952584
# WritingScore   0.807118      0.952584      1.000000

# %% [markdown]
# ### Conclussion:
#   - MathScore and ReadingScore have a strong positive correlation of 0.818.
#   - MathScore and WritingScore also show a strong positive correlation of 0.807.
#   - ReadingScore and WritingScore exhibit a very strong positive correlation of 0.953.
#
#   These correlations indicate that students who perform well in one subject tend to perform well in the others as well, especially between Reading and Writing scores.

# %%
df[['MathScore','ReadingScore', 'WritingScore']].cov()
# Out:
#                MathScore  ReadingScore  WritingScore
# MathScore     235.979234    185.418355    191.478700
# ReadingScore  185.418355    217.826655    217.122793
# WritingScore  191.478700    217.122793    238.502459

# %% [markdown]
# ### Conclussion:
#   - The covariance matrix shows how much two scores vary together. For instance, MathScore and ReadingScore have a covariance of approximately 185.42, and MathScore and WritingScore have a covariance of 191.48. This suggests similar variability and directionality in their fluctuations.

# %%
df[['MathScore','ReadingScore', 'WritingScore']].skew()
# Out:
# MathScore      -0.162862
# ReadingScore   -0.181288
# WritingScore   -0.159830
# dtype: float64

# %% [markdown]
# ### Conclussion:
#   - The skewness values for MathScore, ReadingScore, and WritingScore are all negative, indicating a slight leftward skew in their distributions. This suggests that while the majority of students perform around the mean, there are fewer students with very low scores compared to very high scores.

# %% [markdown]
# ## Multivariate Analysis

# %%
# Relation between Parental Education Level and Marks
sns.heatmap(df.groupby('ParentEduc')[['MathScore','ReadingScore', 'WritingScore']].mean(),annot=True)
plt.title('Average Scores by Parental Education Level')
plt.xlabel('Test Subject (MathScore, ReadingScore, WritingScore)')
plt.ylabel('Parental Education Level')
plt.show()

# %% [markdown]
# ### Conclussion:
#
# - Master's Degree: Students whose parents have a master's degree tend to have the highest average scores in Math, Reading, and Writing, with scores ranging from approximately 72 to 76.
# - Bachelor's Degree: Similarly, students from households where parents hold a bachelor's degree also perform well, with average scores ranging from around 70 to 73 across the three subjects.
# - Associate's Degree: Students with parents holding an associate's degree also achieve moderate scores, with averages around 68 to 71.
# - Some College: Scores for students whose parents attended some college are slightly lower, with averages ranging from approximately 66 to 69.
# - High School: Students from households where parents completed high school have lower average scores, ranging from about 64 to 67.
# - Some High School: The lowest average scores are observed among students whose parents have some high school education, with averages ranging from approximately 62 to 65.
# - Unknown: Students with unknown parental education levels show average scores similar to those with some college education, with averages around 66 to 69.
#
# Overall, higher parental education levels correlate positively with higher average scores in Math, Reading, and Writing among students. This suggests that parental education plays a significant role in student academic achievement across these subjects.

# %%
# Relation between Parental Marital Status and Marks
sns.heatmap(df.groupby('ParentMaritalStatus')[['MathScore','ReadingScore', 'WritingScore']].mean(),annot=True)
plt.title('Average Scores by Parental Marital Status')
plt.xlabel('Test Subject (MathScore, ReadingScore, WritingScore)')
plt.ylabel('Parental Marital Status')
plt.show()

# %% [markdown]
# ### Conclussion:
# - Widowed: Students from widowed households tend to have the highest average scores in Math, Reading, and Writing, with scores ranging from approximately 67 to 69.
# - Divorced: Students from divorced households also achieve relatively high scores, with averages ranging from around 66 to 69 across the three subjects.
# - Married: Scores for students from married households are similar to those from divorced and widowed households, with averages ranging from approximately 66 to 69.
# - Unknown: Students with unknown parental marital status show average scores similar to those from married and divorced households, with averages around 66 to 69.
# - Single: The lowest average scores are observed among students from single-parent households, with averages ranging from approximately 66 to 69.
#
# Overall, there are minor variations in average scores across different parental marital statuses, with widowed and divorced households showing slightly higher scores compared to married, unknown, and single-parent households. This suggests that while parental marital status may influence student performance to some extent, other factors such as parental involvement, socioeconomic status, and educational support also play crucial roles in academic achievement.

# %%
sns.heatmap(df.groupby('NrSiblings')[['MathScore','ReadingScore', 'WritingScore']].mean(),annot=True)
plt.title('Average Scores by Number of Siblings')
plt.xlabel('Test Subject (MathScore, ReadingScore, WritingScore)')
plt.ylabel('Number of Siblings')
plt.show()

# %% [markdown]
# ### Conclussion:
# - 0 Siblings: Students with no siblings have average scores ranging from approximately 66.7 in Math, 69.4 in Reading, and 68.5 in Writing.
# - 1 Sibling: Scores are slightly lower for students with 1 sibling, with averages around 66.5 in Math, 69.3 in Reading, and 68.2 in Writing.
# - 2 Siblings: Similar to students with 1 sibling, those with 2 siblings also show averages close to 66.6 in Math, 69.5 in Reading, and 68.5 in Writing.
# - 3 Siblings: Students with 3 siblings have slightly higher average scores compared to those with fewer siblings, with averages around 66.7 in Math, 69.5 in Reading, and 68.7 in Writing.
# - 4 Siblings: Scores dip slightly for students with 4 siblings, with averages approximately 66.2 in Math, 69.1 in Reading, and 68.1 in Writing.
# - 5 Siblings: Similar to students with 0 siblings, those with 5 siblings show averages around 66.6 in Math, 69.5 in Reading, and 68.3 in Writing.
# - 6 Siblings: Scores decrease further for students with 6 siblings, with averages approximately 65.9 in Math, 68.8 in Reading, and 67.9 in Writing.
# - 7 Siblings: Students with 7 siblings have the highest average scores across all groups, with averages around 67.6 in Math, 69.8 in Reading, and 69.0 in Writing.
#
# Overall, the number of siblings does not show a consistent trend in influencing average scores across Math, Reading, and Writing. However, students with 7 siblings tend to have slightly higher average scores compared to those with fewer siblings. This suggests that while family size may have some impact on academic performance, individual circumstances and other factors likely play significant roles as well.

# %%
sns.heatmap(df.groupby('PracticeSport')[['MathScore','ReadingScore', 'WritingScore']].mean(),annot=True)
plt.title('Average Scores by Sports Involvement')
plt.xlabel('Test Subject (MathScore, ReadingScore, WritingScore)')
plt.ylabel('Sports Involvement')
plt.show()

# %% [markdown]
# ### Conclussion:
# - Never: Students who never practice sports have the lowest average scores across Math, Reading, and Writing, with averages around 64.5 in Math, 68.5 in Reading, and 66.8 in Writing.
# - Regularly: Students who regularly practice sports show the highest average scores among the groups, with averages approximately 67.8 in Math, 69.9 in Reading, and 69.6 in Writing.
# - Sometimes: Students who sometimes practice sports fall between the other two groups, with averages around 66.3 in Math, 69.2 in Reading, and 68.1 in Writing.
#
# This suggests a positive correlation between regular sports involvement and academic performance, particularly in Reading and Writing scores. Regular sports participation might contribute to better concentration, discipline, and overall well-being, which could positively impact academic achievements. However, further studies would be needed to establish causal relationships between sports participation and academic performance.

# %%
sns.heatmap(df.groupby('TestPrep')[['MathScore','ReadingScore', 'WritingScore']].mean(),annot=True)
plt.title('Average Scores by Test Preparation')
plt.xlabel('Test Subject (MathScore, ReadingScore, WritingScore)')
plt.ylabel('Test Preparation')
plt.show()

# %% [markdown]
# ### Conclussion:
# - Completed Test Preparation: Students who completed test preparation activities have higher average scores across Math, Reading, and Writing. Specifically, their average scores are approximately 69.5 in Math, 73.7 in Reading, and 74.7 in Writing.
#
# - No Test Preparation: Students who did not complete test preparation activities show lower average scores compared to those who completed preparation. Their average scores are around 65.1 in Math, 67.3 in Reading, and 65.4 in Writing.
#
# This indicates a clear correlation between completing test preparation and higher academic performance in all subjects—Math, Reading, and Writing. Students who engaged in test preparation activities likely benefited from structured study techniques, familiarity with test formats, and increased confidence during exams. The difference in scores underscores the importance of proactive test preparation in achieving better academic outcomes.

# %%
sns.heatmap(df.groupby('WklyStudyHours')[['MathScore','ReadingScore', 'WritingScore']].mean(),annot=True)
plt.title('Average Scores by Parental Education Level')
plt.xlabel('Test Subject (MathScore, ReadingScore, WritingScore)')
plt.ylabel('Parental Education Level')
plt.show()

# %% [markdown]
# ### Conclussion:
# - 5 - 10 Hours per Week: Students who study 5 to 10 hours per week have average scores of approximately 66.9 in Math, 69.7 in Reading, and 68.6 in Writing.
#
# - Less than 5 Hours per Week: Students who study less than 5 hours per week show average scores around 64.6 in Math, 68.2 in Reading, and 67.1 in Writing.
#
# - More than 10 Hours per Week: Students who study more than 10 hours per week have higher average scores compared to other groups. Their scores are about 68.7 in Math, 70.4 in Reading, and 69.8 in Writing.
#
# This analysis suggests that there is a positive correlation between increased weekly study hours and higher academic performance in Math, Reading, and Writing. Students who dedicate more time to studying tend to achieve better results across all subjects, highlighting the importance of consistent and sufficient study habits in academic success.

# %% [markdown]
# ## Conclussion :
#
# 1. Parental Education:
# Higher levels of parental education, particularly master's and bachelor's degrees, correlate with higher average scores in Math, Reading, and Writing. This suggests that parental educational attainment plays a significant role in shaping academic outcomes.
#
#
# 2. Parent Marital Status:
# There is minimal variation in academic performance across different parental marital statuses (married, single, divorced, widowed). This indicates that marital status alone may not strongly influence academic performance compared to other factors.
#
#
# 3. Number of Siblings:
# The number of siblings does not show a clear pattern of influence on academic scores, as the average scores remain relatively consistent across different sibling counts.
#
#
# 4. Sports Involvement:
# Students who participate in sports regularly tend to have higher average scores in Math, Reading, and Writing compared to those who never or only sometimes participate. This suggests a positive association between regular sports involvement and academic performance.
#
#
# 5. Test Preparation:
# Students who complete test preparation courses achieve notably higher average scores in Math, Reading, and Writing compared to those who do not undertake such preparations.
#
#
# 6. Weekly Study Hours:
# Higher weekly study hours (>10 hours) are associated with better academic performance across all subjects (Math, Reading, and Writing) compared to lower study hours (<5 hours).
#
#
# These findings underscore the multifaceted nature of factors influencing academic success. While parental education and test preparation play crucial roles, activities like sports involvement and dedicated study hours also contribute significantly to enhanced academic performance. Understanding these factors can guide educational strategies and interventions aimed at improving student outcomes.

# %% [markdown]
# ### Relationship between each scores

# %%
sns.scatterplot(data=df,x='ReadingScore', y='WritingScore',hue='Gender')
plt.title('Reading Score Vs Writing Score')
plt.xlabel('Reading Score')
plt.ylabel('Writing Score')
plt.show()

# %%
sns.scatterplot(data=df,x='MathScore', y='ReadingScore',hue='Gender')
plt.title('Math Score Vs Reading Score')
plt.xlabel('Math Score')
plt.ylabel('Reading Score')
plt.show()

# %%
sns.scatterplot(data=df,x='MathScore', y='WritingScore',hue='Gender')
plt.title('Math Score Vs Writing Score')
plt.xlabel('Math Score')
plt.ylabel('Writing Score')
plt.show()

# %%
# Comparison of academic scores between genders
# Set the figure size
plt.figure(figsize=(15, 5))
# Math Score comparison
plt.subplot(1, 3, 1)
sns.barplot(x='Gender', y='MathScore', data=df)
plt.title('Math Score by Gender')
plt.xlabel('Gender')
plt.ylabel('Math Score')

# Reading Score comparison
plt.subplot(1, 3, 2)
sns.barplot(x='Gender', y='ReadingScore', data=df)
plt.title('Reading Score by Gender')
plt.xlabel('Gender')
plt.ylabel('Reading Score')

# Writing Score comparison
plt.subplot(1, 3, 3)
sns.barplot(x='Gender', y='WritingScore', data=df)
plt.title('Writing Score by Gender')
plt.xlabel('Gender')
plt.ylabel('Writing Score')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Conclusion:
#
# The comparison of academic scores between genders reveals interesting insights:
#
# - Math Score: On average, males tend to perform slightly better in Math compared to females. This trend is consistent across the dataset, suggesting a potential area for further exploration in educational strategies or gender-specific learning approaches.
#
# - Reading Score: Females generally outperform males in Reading. This observation highlights a notable gender difference where females show stronger performance in reading comprehension tasks.
#
# - Writing Score: Similar to Reading, females also demonstrate higher average scores in Writing compared to males. This finding underscores a potential disparity in writing skills between genders that could influence curriculum design and instructional methods.
#
# These gender-based differences in academic performance across Math, Reading, and Writing scores provide valuable insights for educators and policymakers aiming to optimize learning outcomes and support diverse student needs effectively. Further research could delve into the underlying factors contributing to these disparities and explore targeted interventions to promote equitable academic achievement across genders.

# %%
# Comparison of academic scores between Ethnic Group
# Set the figure size
plt.figure(figsize=(15, 5))
# Math Score comparison
plt.subplot(1, 3, 1)
sns.barplot(x='EthnicGroup', y='MathScore', data=df)
plt.title('Math Score by Ethnic Group')
plt.xlabel('Ethnic Group')
plt.ylabel('Math Score')
plt.xticks(rotation=45)  # Rotate x-axis labels if needed for better readability

# Reading Score comparison
plt.subplot(1, 3, 2)
sns.barplot(x='EthnicGroup', y='ReadingScore', data=df)
plt.title('Reading Score by Ethnic Group')
plt.xlabel('Ethnic Group')
plt.ylabel('Reading Score')
plt.xticks(rotation=45)

# Writing Score comparison
plt.subplot(1, 3, 3)
sns.barplot(x='EthnicGroup', y='WritingScore', data=df)
plt.title('Writing Score by Ethnic Group')
plt.xlabel('Ethnic Group')
plt.ylabel('Writing Score')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Conclussion:
#
# 1. Math Score by Ethnic Group:
#    - Group E tends to have the highest average Math scores among all ethnic groups.
#    - Group D follows closely behind Group E.
#    - Group C and Group B show moderate Math scores.
#    - Group A generally has the lowest average Math scores compared to other groups.
#
# 2. Reading Score by Ethnic Group:
#    - Group E also shows higher average Reading scores, similar to their Math scores.
#    - Group D follows with slightly lower but still competitive Reading scores.
#    - Group C and Group B exhibit moderate Reading scores.
#    - Group A continues to have the lowest average Reading scores.
#
# 3. Writing Score by Ethnic Group:
#    - Group E maintains higher average Writing scores, consistent with their Math and Reading scores.
#    - Group D follows with competitive Writing scores, albeit slightly lower than Group E.
#    - Group C and Group B show moderate Writing scores.
#    - Group A again demonstrates the lowest average Writing scores compared to other groups.
#
# ### Overall Observation:
# - Performance Disparities: There is noticeable variation in academic performance across different ethnic groups, with Group E consistently outperforming other groups in Math, Reading, and Writing scores.
# - Educational Interventions: Understanding these disparities can inform targeted educational interventions and support strategies to bridge gaps and improve academic outcomes, particularly for groups with lower average scores like Group A.
# - Further Analysis: Further exploration into socioeconomic factors, access to resources, and educational support systems could provide deeper insights into these performance differences.

# %% [markdown]
# ## Conclussion:
# Based on the comprehensive analysis of student performance data across various demographic and academic factors, several key insights have emerged:
#
# 1. **Gender Comparison**:
#    - There is a noticeable difference in academic performance between genders, with females generally outperforming males across Math, Reading, and Writing scores.
#
# 2. **Ethnic Group Comparison**:
#    - Group E consistently demonstrates higher average scores in Math, Reading, and Writing compared to other ethnic groups, while Group A consistently shows lower average scores.
#
# 3. **Parental Education Impact**:
#    - Students with parents holding master's degrees tend to achieve higher scores in all subjects compared to those with lower levels of parental education.
#
# 4. **Parent Marital Status and Sibling Count**:
#    - There is minimal variation in academic performance based on parental marital status or number of siblings, suggesting these factors have limited impact on scores.
#
# 5. **Lunch Type and Test Preparation**:
#    - Students who receive standard lunches and complete test preparations tend to achieve higher scores compared to those on free/reduced lunches and who do not complete test preparations.
#
# 6. **Sports Involvement and Study Hours**:
#    - Regularly practicing sports and dedicating more weekly study hours (>10 hours) are associated with higher academic performance across all subjects.
#
# 7. **Transport Medium and Weekly Study Hours**:
#    - Students using private transport mediums and studying between 5-10 hours per week also demonstrate higher academic performance.
#
# 8. **Overall Observations**:
#    - The data highlights significant disparities in academic performance based on gender, ethnicity, parental education, and lifestyle factors such as sports involvement and study habits.
#    - These insights underscore the importance of targeted interventions and support systems to address performance gaps and promote equitable educational outcomes.
#
# ### Recommendations:
# - **Targeted Support Programs**: Implement programs aimed at supporting underperforming groups, particularly focusing on improving access to resources and educational support.
# - **Enhanced Parental Involvement**: Encourage parental involvement and provide resources to support student learning at home.
# - **Promote Healthy Lifestyles**: Emphasize the benefits of sports participation and effective study habits to enhance overall academic performance.
#
# By leveraging these insights and recommendations, educational institutions can foster an environment conducive to academic success for all students, regardless of background or demographic factors.
